# %% [markdown]
# <a href="https://colab.research.google.com/github/YasmineeBa/coco2yolo_bdd100k_data/blob/main/convert_bdd10k_into_yolo_format.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copyfile("/content/drive/MyDrive/bdd100k/bdd100k_train_pan.json","/content/bdd100k_train_pan.json")
shutil.copyfile("/content/drive/MyDrive/bdd100k/bdd100k_val_pan.json","/content/bbdd100k_val_pan.json")
# Out:
# '/content/bbdd100k_val_pan.json'

# %%
shutil.copyfile("/content/drive/MyDrive/bdd100k/bdd100k_images_10k.zip","/content/bdd100k_images_10k.zip")
# Out:
# '/content/bdd100k_images_10k.zip'

# %%
# !unzip bdd100k_images_10k.zip -d /content/

# %%
# !unzip bdd100k_splited.zip -d /content/
# Out:
# Archive:  bdd100k_splited.zip
# replace /content/bdd100k_image_307.json? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
shutil.copyfile("/content/drive/MyDrive/bdd100k/bdd100k_splited.zip","/content/bdd100k_splited.zip")
# Out:
# '/content/bdd100k_splited.zip'

# %%
# !rm bdd100k_images_10k.zip

# %%
# %ls /content/drive/MyDrive/bdd100k/
# Out:
# bdd100k_images_100k.zip              bdd100k_splited.zip
# bdd100k_images_10k.zip               bdd100k_train.json
# bdd100k_info.zip                     bdd100k_train_pan.json
# bdd100k_ins_seg_labels_trainval.zip  bdd100k_val.json
# bdd100k_labels_release.zip           bdd100k_val_pan.json
# bdd100k_pan_seg_labels_trainval.zip  dataset.zip

# %%
for col in dataset.df.columns:
  print(col)
# Out:
# img_folder
# img_filename
# img_path
# img_id
# img_width
# img_height
# img_depth
# ann_segmented
# ann_bbox_xmin
# ann_bbox_ymin
# ann_bbox_xmax
# ann_bbox_ymax
# ann_bbox_width
# ann_bbox_height
# ann_area
# ann_segmentation
# ann_iscrowd
# ann_pose
# ann_truncated
# ann_difficult
# cat_id
# cat_name
# cat_supercategory
# split
# annotated

# %%
# Conver to numpy array
col_list = dataset.df['cat_id'].unique()
print(col_list)
# Out:
# ['2' '12' '11' '1' '3' '8' '6' '10' '4' '9' '7' '5' '']

# %%
# Conver to numpy array
col_list = dataset.df['cat_name'].unique()
print(col_list)
# Out:
# ['person' 'traffic sign' 'traffic light' 'car' 'truck' 'motorcycle'
#  'rider' 'train' 'bus' 'caravan' 'trailer' 'bicycle' '']

# %%
dataset.path_to_annotations = "data/yolo"
dataset.export.ExportToYoloV5()[0]
# Out:
# Exporting YOLO files...: 100%|██████████| 7000/7000 [01:26<00:00, 81.16it/s]
# 'training/dataset.yaml'

# %% [markdown]
# ### Val file

# %%
path_to_annotations = "/content/bbdd100k_val_pan.json"

# %%
dataset_val = importer.ImportCoco(path=path_to_annotations, path_to_images=path_to_images)

# %%
dataset_val.path_to_annotations = "data/"
dataset_val.export.ExportToYoloV5()[0]
# Out:
# Exporting YOLO files...: 100%|██████████| 1000/1000 [00:03<00:00, 298.71it/s]
# 'training/dataset.yaml'

# %%
import os
sizefile= os.listdir('/content/train/labels')
print(len(sizefile))
# Out:
# 7000

# %%
import os
sizefile= os.listdir('/content/training/labels')
print(len(sizefile))
# Out:
# 1000

# %%
shutil.make_archive('train', 'zip', '/content/train')
# Out:
# '/content/train.zip'

# %%
shutil.make_archive('val', 'zip', '/content/val')
# Out:
# '/content/val.zip'

# %%
shutil.copyfile("/content/train.zip", "/content/drive/MyDrive/bdd100k_data/bdd10k_labels_yolo/train.zip")
# Out:
# '/content/drive/MyDrive/bdd100k_data/bdd10k_labels_yolo/train.zip'

# %%
shutil.copyfile("/content/val.zip", "/content/drive/MyDrive/bdd100k_data/bdd10k_labels_yolo/val.zip")
# Out:
# '/content/drive/MyDrive/bdd100k_data/bdd10k_labels_yolo/val.zip'

# %%
# %ls /content/drive/MyDrive/bdd100k_data/bdd10k_labels_yolo/
# Out:
# train.zip

# %%
# apres ca vous devez cree deux dossier un pour train w autre pour val, dans train mettre images train w labels, same for val images

# %%
# !rm /content/train.zip
# !rm /content/val.zip

# %% [markdown]
# ### train et val format tu les trouves partagé avec toi dans le drive

# %% [markdown]
# # Convert train folder
#  - from coco format into yolo format

# %%
import json

f = open('/content/bdd100k_train_pan.json', 'r')
data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['images', 'categories', 'annotations'])

# %%
data['categories']
# Out:
# [{'id': 1, 'name': 'car'},
#  {'id': 2, 'name': 'person'},
#  {'id': 3, 'name': 'truck'},
#  {'id': 4, 'name': 'bus'},
#  {'id': 5, 'name': 'bicycle'},
#  {'id': 6, 'name': 'rider'},
#  {'id': 7, 'name': 'trailer'},
#  {'id': 8, 'name': 'motorcycle'},
#  {'id': 9, 'name': 'caravan'},
#  {'id': 10, 'name': 'train'},
#  {'id': 11, 'name': 'traffic light'},
#  {'id': 12, 'name': 'traffic sign'}]

# %%
data['annotations'][1]
# Out:
# {'segmentation': [[570.70884,
#    92.36160999999998,
#    589.01761,
#    93.24752,
#    588.72231,
#    129.27445999999998,
#    569.52763,
#    128.97915999999998]],
#  'area': 719.4307082429979,
#  'iscrowd': 0,
#  'image_id': 0,
#  'bbox': [569.52763, 92.36160999999998, 19.489979999999946, 36.91284999999999],
#  'category_id': 12,
#  'id': 2}

# %%
f.close()

# %%
import os
import matplotlib.pyplot as plt
import shutil
import json

# %%
input_path = "/content/bdd100k/images/10k/train/"
output_path = "/content/yolo_dataset/"

# %%
file_names = []

def load_images_from_folder(folder):
  count = 0
  for filename in os.listdir(folder):
        source = os.path.join(folder,filename)
        destination = f"{output_path}images/img{count}.jpg"

        try:
            shutil.copy(source, destination)
            print("File copied successfully.")
        # If source and destination are same
        except shutil.SameFileError:
            print("Source and destination represents the same file.")

        file_names.append(filename)
        count += 1

load_images_from_folder('/content/bdd100k/images/10k/train')
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# ...

# %%
print(len(os.listdir('/content/yolo_dataset/images')))
# Out:
# 7000

# %%
def get_img_ann(image_id):
    img_ann = []
    isFound = False
    for ann in data['annotations']:
        if ann['image_id'] == image_id:
            img_ann.append(ann)
            isFound = True
    if isFound:
        return img_ann
    else:
        return None

# %%
def get_img(filename):
  for img in data['images']:
    if img['file_name'] == filename:
      return img

# %%
data['images'][0]
# Out:
# {'id': 0, 'width': 1280, 'height': 720, 'file_name': '5edb27ac-92d9f34d.jpg'}

# %%
filenam = '5edb27ac-92d9f34d.jpg'
img = get_img(filenam)
img_id = img['id']
img_w = img['width']
img_h = img['height']

# %%
print(img_id, img_w, img_h)
# Out:
# 0 1280 720

# %%
img = get_img_ann(img_id)
img

# %% [markdown]
# ## Applying Conversion.
# Following are the steps we are going to perform in conversion:
#
#     Extracting image information such as image_id, image_width, image_height, etc.
#     Get annotations for this image using image_id.
#     Open a text file for this image in the output path given by the user.
#     Extract bounding box properties for each object in the image.
#     Finding midpoint coordinates.
#     Apply Normalization.
#     Setting precision.
#     Writing the updated annotations for this image into a text file.
#     After processing through all the annotations for the current image, close the text file.
#     Repeat the steps for all images.

# %%
count = 0
for filename in file_names:
  # Extracting image 
  img = get_img(filename)
  img_id = img['id']
  img_w = img['width']
  img_h = img['height']

  # Get Annotations for this image
  img_ann = get_img_ann(img_id)

  if img_ann:
    # Opening file for current image
    file_object = open(f"{output_path}labels/img{count}.txt", "a")

    for ann in img_ann:
      current_category = ann['category_id'] - 1 # As yolo format labels start from 0 
      current_bbox = ann['bbox']
      x = current_bbox[0]
      y = current_bbox[1]
      w = current_bbox[2]
      h = current_bbox[3]
      
      # Finding midpoints
      x_centre = (x + (x+w))/2
      y_centre = (y + (y+h))/2
      
      # Normalization
      x_centre = x_centre / img_w
      y_centre = y_centre / img_h
      w = w / img_w
      h = h / img_h
      
      # Limiting upto fix number of decimal places
      x_centre = format(x_centre, '.6f')
      y_centre = format(y_centre, '.6f')
      w = format(w, '.6f')
      h = format(h, '.6f')
          
      # Writing current object 
      file_object.write(f"{current_category} {x_centre} {y_centre} {w} {h}\n")

    file_object.close()
    count += 1  # This should be outside the if img_ann block.

# %%
filename=
  # Extracting image 
  img = get_img(filename)
  img_id = img['id']
  img_w = img['width']
  img_h = img['height']

  # Get Annotations for this image
  img_ann = get_img_ann(img_id)

  if img_ann:
    # Opening file for current image
    file_object = open(f"{output_path}labels/img{count}.txt", "a")

    for ann in img_ann:
      current_category = ann['category_id']

# %% [markdown]
# # Convert val folder into yolo format

# %%
import json

ff = open('/content/bbdd100k_val_pan.json', 'r')
data_val = json.load(ff)

# %%
data_val.keys()
# Out:
# dict_keys(['images', 'categories', 'annotations'])

# %%
data_val['categories']
# Out:
# [{'id': 1, 'name': 'car'},
#  {'id': 2, 'name': 'person'},
#  {'id': 3, 'name': 'truck'},
#  {'id': 4, 'name': 'bus'},
#  {'id': 5, 'name': 'bicycle'},
#  {'id': 6, 'name': 'rider'},
#  {'id': 7, 'name': 'trailer'},
#  {'id': 8, 'name': 'motorcycle'},
#  {'id': 9, 'name': 'caravan'},
#  {'id': 10, 'name': 'train'},
#  {'id': 11, 'name': 'traffic light'},
#  {'id': 12, 'name': 'traffic sign'}]

# %%
data_val['annotations'][0]
# Out:
# {'segmentation': [[403.2857422452333,
#    393.1936808021726,
#    402.70217326246416,
#    394.03746605389597,
#    402.190798380656,
#    394.7819824524754,
#    401.75161759980904,
#    395.42722999791096,
#    401.38463091992327,
#    395.9732086902026,
#    401.0898383409986,
#    396.4199185293503,
#    400.8672398630351,
#    396.7673595153541,
#    400.7168354860327,
#    397.01553164821394,
#    400.63862520999146,
#    397.1644349279298,
#    400.63260903491135,
#    397.21406935450176,
#    399.51961664509383,
#    397.2336223104241,
#    398.5269477568782,
#    397.292281178191,
#    397.6546023702643,
#    397.3900459578024,
#    396.9025804852524,
#    397.5269166492584,
#    396.2708821018424,
#    397.70289325255897,
#    395.7595072200343,
#    397.9179757677042,
#    395.36845583982813,
#    398.1721641946939,
#    395.0977279612239,
#    398.4654585335283,
#    394.9473235842215,
#    398.7978587842072,
#    394.917242708821,
#    399.1693649467307,
# ...

# %%
input_path = "/content/bdd100k/images/10k/val/"
output_path = "/content/yolo_dataset/val/"

# %%
file_names = []

def load_images_from_folder(folder):
  count = 0
  for filename in os.listdir(folder):
        source = os.path.join(folder,filename)
        destination = f"{output_path}images/img{count}.jpg"

        try:
            shutil.copy(source, destination)
            print("File copied successfully.")
        # If source and destination are same
        except shutil.SameFileError:
            print("Source and destination represents the same file.")

        file_names.append(filename)
        count += 1

load_images_from_folder('/content/bdd100k/images/10k/val')
# Out:
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# File copied successfully.
# ...

# %%
print(len(os.listdir('/content/yolo_dataset/val/images')))
# Out:
# 1000

# %%
def get_img_ann_val(image_id):
    img_ann = []
    isFound = False
    for ann in data_val['annotations']:
        if ann['image_id'] == image_id:
            img_ann.append(ann)
            isFound = True
    if isFound:
        return img_ann
    else:
        return None

# %%
def get_img_val(filename):
  for img in data_val['images']:
    if img['file_name'] == filename:
      return img

# %%
count = 0

for filename in file_names:
  # Extracting image 
  img = get_img_val(filename)
  img_id = img['id']
  img_w = img['width']
  img_h = img['height']

  # Get Annotations for this image
  img_ann = get_img_ann_val(img_id)

  if img_ann:
    # Opening file for current image
    file_object = open(f"{output_path}labels/img{count}.txt", "a")

    for ann in img_ann:
      current_category = ann['category_id'] - 1 # As yolo format labels start from 0 
      current_bbox = ann['bbox']
      x = current_bbox[0]
      y = current_bbox[1]
      w = current_bbox[2]
      h = current_bbox[3]
      
      # Finding midpoints
      x_centre = (x + (x+w))/2
      y_centre = (y + (y+h))/2
      
      # Normalization
      x_centre = x_centre / img_w
      y_centre = y_centre / img_h
      w = w / img_w
      h = h / img_h
      
      # Limiting upto fix number of decimal places
      x_centre = format(x_centre, '.6f')
      y_centre = format(y_centre, '.6f')
      w = format(w, '.6f')
      h = format(h, '.6f')
          
      # Writing current object 
      file_object.write(f"{current_category} {x_centre} {y_centre} {w} {h}\n")

    file_object.close()
    count += 1  # This should be outside the if img_ann block.

# %%
print(len(os.listdir('/content/yolo_dataset/val/labels')))
# Out:
# 990

# %% [markdown]
# ### to delete the image files that don't have corresponding label files, you can use the script as follows:

# %%
import os

# Specify the folder paths
image_folder = "/content/yolo_dataset/val/images"
label_folder = "/content/yolo_dataset/val/labels"

# List all the filenames in each folder
image_filenames = set(os.listdir(image_folder))
label_filenames = set(os.listdir(label_folder))

# Remove the file extensions from the label filenames
label_basenames = {os.path.splitext(filename)[0] for filename in label_filenames}

# Iterate through the image filenames and check if there's a corresponding label file
for image_filename in image_filenames:
    image_basename, ext = os.path.splitext(image_filename)

    # If the image file doesn't have a corresponding label file, delete the image file
    if image_basename not in label_basenames:
        image_file_path = os.path.join(image_folder, image_filename)
        os.remove(image_file_path)
        print(f"Deleted: {image_file_path}")
# Out:
# Deleted: /content/yolo_dataset/val/images/img992.jpg
# Deleted: /content/yolo_dataset/val/images/img991.jpg
# Deleted: /content/yolo_dataset/val/images/img996.jpg
# Deleted: /content/yolo_dataset/val/images/img993.jpg
# Deleted: /content/yolo_dataset/val/images/img990.jpg
# Deleted: /content/yolo_dataset/val/images/img998.jpg
# Deleted: /content/yolo_dataset/val/images/img999.jpg
# Deleted: /content/yolo_dataset/val/images/img997.jpg
# Deleted: /content/yolo_dataset/val/images/img994.jpg
# Deleted: /content/yolo_dataset/val/images/img995.jpg

# %%
#%cp -r /content/bdd100k/images/10k/test/ -d /content/yolo_dataset/test/

# %%
print(len(os.listdir('/content/yolo_dataset/test/test')))
# Out:
# 2000

# %%
shutil.make_archive('/content/drive/MyDrive/bdd100k_data/yolo_dataset/', 'zip','/content/yolo_dataset' )
# Out:
# '/content/drive/MyDrive/bdd100k_data/yolo_dataset.zip'
